# %%
#dependencies
import pandas as pd
from pathlib import Path

# %%
#import csv file
file_path = Path(r"C:\Users\tsatr\Documents\BootCamp\18-Tableau\02-Homework\Resources\201812_citibike_tripdata.csv")
dec_df = pd.read_csv(file_path)
dec_df.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           689   00:04.3  11:33.8            3359.0
# 1           204   00:05.5  03:30.5            3504.0
# 2           316   00:10.2  05:27.2             270.0
# 3           726   00:22.0  12:28.2             495.0
# 4           397   00:29.6  07:07.4             473.0
#
#            start station name  start station latitude  \
# 0       E 68 St & Madison Ave               40.769157
# 1    E 123 St & Lexington Ave               40.802926
# 2     Adelphi St & Myrtle Ave               40.693083
# 3            W 47 St & 10 Ave               40.762699
# 4  Rivington St & Chrystie St               40.721101
#
#    start station longitude  end station id            end station name  \
# 0               -73.967035           164.0             E 47 St & 2 Ave
# 1               -73.937900          3490.0            E 116 St & 2 Ave
# 2               -73.971789           243.0     Fulton St & Rockwell Pl
# ...

# %%
#import csv file
file_path = Path(r"C:\Users\tsatr\Documents\BootCamp\18-Tableau\02-Homework\Resources\201901_citibike_tripdata.csv")
jan_df = pd.read_csv(file_path)
jan_df.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           320   01:47.4  07:07.6            3160.0
# 1           316   04:43.7  10:00.6             519.0
# 2           591   06:04.0  15:55.4            3171.0
# 3          2719   07:03.5  52:22.6             504.0
# 4           303   07:35.9  12:39.5             229.0
#
#             start station name  start station latitude  \
# 0  Central Park West & W 76 St               40.778968
# 1        Pershing Square North               40.751873
# 2      Amsterdam Ave & W 82 St               40.785247
# 3              1 Ave & E 16 St               40.732219
# 4               Great Jones St               40.727434
#
#    start station longitude  end station id        end station name  \
# 0               -73.973747          3283.0  W 89 St & Columbus Ave
# 1               -73.977706           518.0         E 39 St & 2 Ave
# 2               -73.976673          3154.0         E 77 St & 3 Ave
# ...

# %%
#import csv file
file_path = Path(r"C:\Users\tsatr\Documents\BootCamp\18-Tableau\02-Homework\Resources\201902_citibike_tripdata.csv")
feb_df = pd.read_csv(file_path)
feb_df.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           219   00:06.3  03:46.1            3494.0
# 1           143   00:28.0  02:51.7             438.0
# 2           296   01:14.0  06:10.7            3571.0
# 3           478   01:14.2  09:12.8             167.0
# 4           225   01:49.3  05:34.5            3458.0
#
#          start station name  start station latitude  start station longitude  \
# 0  E 115 St & Lexington Ave               40.797911               -73.942300
# 1       St Marks Pl & 1 Ave               40.727791               -73.985649
# 2   Bedford Ave & Bergen St               40.676368               -73.952918
# 3           E 39 St & 3 Ave               40.748901               -73.976049
# 4           W 55 St & 6 Ave               40.763094               -73.978350
#
#    end station id        end station name  end station latitude  \
# 0          3501.0  E 118 St & Madison Ave             40.801487
# ...

# %%
pd.concat([dec_df, jan_df, feb_df]).to_csv('winter2019.csv', index=False)

# %%
file_path = Path(r"C:\Users\tsatr\Documents\BootCamp\18-Tableau\02-Homework\winter2019.csv")
winter2019_df = pd.read_csv(file_path)
winter2019_df.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           689   00:04.3  11:33.8            3359.0
# 1           204   00:05.5  03:30.5            3504.0
# 2           316   00:10.2  05:27.2             270.0
# 3           726   00:22.0  12:28.2             495.0
# 4           397   00:29.6  07:07.4             473.0
#
#            start station name  start station latitude  \
# 0       E 68 St & Madison Ave               40.769157
# 1    E 123 St & Lexington Ave               40.802926
# 2     Adelphi St & Myrtle Ave               40.693083
# 3            W 47 St & 10 Ave               40.762699
# 4  Rivington St & Chrystie St               40.721101
#
#    start station longitude  end station id            end station name  \
# 0               -73.967035           164.0             E 47 St & 2 Ave
# 1               -73.937900          3490.0            E 116 St & 2 Ave
# 2               -73.971789           243.0     Fulton St & Rockwell Pl
# ...

# %%
winter2019_df['gender'] = winter2019_df['gender'].replace({0: 'unknown', 1: 'male', 2: 'female'})

# %%
winter2019_df['gender'].value_counts()
# Out:
# male       2177216
# female      633215
# unknown     117105
# Name: gender, dtype: int64

# %%
winter2019g_df = winter2019_df[winter2019_df.gender != 'unknown']

# %%
winter2019g_df['gender'].value_counts()
# Out:
# male      2177216
# female     633215
# Name: gender, dtype: int64

# %%
winter2019g_df.to_csv('winter2019_converted.csv', index=False)

# %%
file_path = Path(r"C:\Users\tsatr\Documents\BootCamp\18-Tableau\02-Homework\summer2019_converted.csv")
summer2019_converted_df = pd.read_csv(file_path)
summer2019_converted_df.head()
# Out:
#    tripduration starttime stoptime  start station id       start station name  \
# 0           330   00:01.5  05:31.8              3602           31 Ave & 34 St
# 1           830   00:04.2  13:55.1              3054  Greene Ave & Throop Ave
# 2           380   00:06.0  06:26.8               229           Great Jones St
# 3          1155   00:06.8  19:22.5              3771  McKibbin St & Bogart St
# 4          1055   00:07.5  17:42.6               441          E 52 St & 2 Ave
#
#    start station latitude  start station longitude  end station id  \
# 0               40.763154               -73.920827            3570
# 1               40.689493               -73.942061            3781
# 2               40.727434               -73.993790             326
# 3               40.706237               -73.933871            3016
# 4               40.756014               -73.967416            3159
#
#         end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
summer2019_cleaned_df = summer2019_converted_df[summer2019_converted_df.gender != 'unknown']

# %%
summer2019_cleaned_df['gender'].value_counts()
# Out:
# male      690975
# female    261990
# Name: gender, dtype: int64

# %%
summer2019_cleaned_df.to_csv('summer2019_cleaned.csv', index=False)
